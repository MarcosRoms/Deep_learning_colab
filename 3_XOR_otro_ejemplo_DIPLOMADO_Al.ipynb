# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosRoms/Deep_learning_colab/blob/main/3_XOR_otro_ejemplo_DIPLOMADO_Al.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Datos de entrenamiento para la compuerta XOR
input_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
target_output = np.array([0, 1, 1, 0])

# Crear el modelo del perceptrón multicapa
model = Sequential()
model.add(Dense(4, input_dim=2, activation='relu'))  # Capa oculta con 4 neuronas y función de activación ReLU
model.add(Dense(1, activation='sigmoid'))           # Capa de salida con 1 neurona y función de activación sigmoide

# Compilar el modelo
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy']) # loss='binary_crossentropy', optimizer='adam', metrics=['acc']

# Entrenar el modelo
epochs = 2500
history = model.fit(input_data, target_output, epochs=epochs, verbose=2)
# Out:
# Epoch 1/2500
# 1/1 - 1s - loss: 0.2420 - binary_accuracy: 0.5000 - 538ms/epoch - 538ms/step
# Epoch 2/2500
# 1/1 - 0s - loss: 0.2417 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 3/2500
# 1/1 - 0s - loss: 0.2415 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 4/2500
# 1/1 - 0s - loss: 0.2412 - binary_accuracy: 0.5000 - 9ms/epoch - 9ms/step
# Epoch 5/2500
# 1/1 - 0s - loss: 0.2409 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 6/2500
# 1/1 - 0s - loss: 0.2407 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# Epoch 7/2500
# 1/1 - 0s - loss: 0.2404 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 8/2500
# 1/1 - 0s - loss: 0.2401 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 9/2500
# 1/1 - 0s - loss: 0.2399 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 10/2500
# 1/1 - 0s - loss: 0.2396 - binary_accuracy: 0.5000 - 6ms/epoch - 6ms/step
# Epoch 11/2500
# 1/1 - 0s - loss: 0.2393 - binary_accuracy: 0.5000 - 5ms/epoch - 5ms/step
# ...

# %%
# Evaluar el modelo entrenado
loss, accuracy = model.evaluate(input_data , target_output)
print(f'Loss: {loss}, Accuracy: {accuracy}')
# Out:
# 1/1 [==============================] - 0s 215ms/step - loss: 0.1269 - binary_accuracy: 0.7500
# Loss: 0.12689122557640076, Accuracy: 0.75

# %%
# Realizar predicciones
test_inputs = np.array([[0,0],[0,1],[1,0],[1,1]])
predictions = model.predict(test_inputs)
print("Predictions:")
for i in range(len(test_inputs)):
    print(f"Input: {test_inputs[i]}, Prediction: {predictions[i][0].round()}")
# Out:
# 1/1 [==============================] - 0s 32ms/step
# Predictions:
# Input: [0 0], Prediction: 1.0
# Input: [0 1], Prediction: 1.0
# Input: [1 0], Prediction: 1.0
# Input: [1 1], Prediction: 0.0

# %%
print('prueba de cambio en google colab')
# Out:
# prueba de cambio en google colab

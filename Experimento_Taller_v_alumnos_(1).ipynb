# %% [markdown]
# <a href="https://colab.research.google.com/github/MarcosRoms/Deep_learning_colab/blob/diplomado/Experimento_Taller_v_alumnos_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Programa para clasificación en agricultura, CEC-UACh, DIPLOMADO CDeIAA

# %% [markdown]
# # Instructor del módulo del Diplomado:
# Dr. Juan Carlos Olguín Rojas

# %% [markdown]
# Experimento para clasificar Manzanas_Taller 09/06/2024

# %% [markdown]
# INICIO:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
from tensorflow import keras

# imprimir la versión de tensorflow
print(tf.__version__)
# Out:
# 2.15.0

# %%
import cv2
# imprimir la versión de tensorflow de OpenCv
print(cv2.__version__)
# Out:
# 4.8.0

# %%
# !cp /content/drive/MyDrive/MANZANAS_COLAB_ZIP_2.zip ../

# %%
import zipfile
import io

# %% [markdown]
# # se crea una carpeta en drive con el nombre: EXPERIMENTO_TALLER

# %% [markdown]
# Copiamos el contenido de (MANZANAS_COLAB_ZIP_2.zip) a la carpeta EXPERIMENTO_TALLER:

# %%
# !unzip /content/drive/MyDrive/MANZANAS_COLAB_ZIP_2.zip -d /content/drive/MyDrive/EXPERIMENTO_TALLER
# Out:
# Archive:  /content/drive/MyDrive/MANZANAS_COLAB_ZIP_2.zip
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1112.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1195.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1201.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1066.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1130.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1160.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1159.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1108.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1088.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1080.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1138.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1228.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1076.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1150.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1216.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1192.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1218.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1146.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1173.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1133.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1176.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1131.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1175.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1196.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1206.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1200.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1123.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1091.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1183.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1193.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1142.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1203.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1139.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1081.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1227.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1230.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1181.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1182.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1179.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1140.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1226.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1105.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1085.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1166.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1157.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1134.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1137.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1116.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1083.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1207.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1129.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1170.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1184.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1223.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1125.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1213.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1197.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1111.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1161.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1093.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1178.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1122.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1077.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1075.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1212.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1162.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1165.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1136.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1104.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1097.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1163.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1171.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1106.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1127.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1089.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1079.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1067.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1168.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1156.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1204.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1113.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1222.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1109.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1128.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1101.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1143.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2789.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1092.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2792.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1185.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1148.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2741.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2821.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (252).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2725.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (195).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Gala_s/ManzanaV_1224.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (131).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2760.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (197).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2745.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (44).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (15).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2722.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2761.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2806.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2769.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (156).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2715.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (235).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (250).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2759.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (173).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2799.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2787.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (8).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2779.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (35).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (47).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (257).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_270.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2742.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2809.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_279.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (59).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2774.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (60).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (91).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (31).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (108).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_911.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2814.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (188).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (219).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2776.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2758.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2785.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2717.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (291).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (109).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2813.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2788.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (244).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (184).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (145).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2816.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2754.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_845.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_263.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_923.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (10).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2803.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (78).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_920.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_300.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_252.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_282.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2733.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2817.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2794.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2755.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (90).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_908.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2738.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_868.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2740.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_838.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_871.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_875.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_842.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_917.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_278.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2793.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2752.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2753.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_859.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_894.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_271.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_258.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_302.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2766.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_886.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_913.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2783.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2797.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_905.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/Red-s (232).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_858.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2749.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_246.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_251.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_269.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_291.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2729.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2775.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_290.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_284.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2750.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_308.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_893.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2800.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2719.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_874.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2718.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2762.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_862.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2739.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_892.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_241.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_305.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2823.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_860.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_272.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_883.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_854.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_265.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2811.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_844.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_243.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_299.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2764.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_865.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_244.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2728.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_896.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_248.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2786.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_881.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_245.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_872.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_242.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2726.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_295.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_239.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2801.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2772.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_264.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_281.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2767.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_255.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2757.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_853.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_866.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2773.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_260.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_900.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_889.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_254.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_253.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2730.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_280.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_259.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2807.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_286.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_276.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_307.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_830.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2784.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2737.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2721.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_840.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_304.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_837.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2778.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_250.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2815.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_879.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_261.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2724.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_848.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_878.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_834.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_877.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_240.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_294.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_292.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2802.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2790.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2798.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2765.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2720.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2744.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2795.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_301.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_266.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2723.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2763.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2780.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_273.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_867.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2819.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2727.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_885.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2812.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_827.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_293.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_249.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_288.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_296.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_855.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2781.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_897.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2748.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_833.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2810.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_247.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_903.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2735.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_856.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_268.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_902.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_901.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2751.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_825.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_267.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_851.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_277.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_910.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_285.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_898.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_890.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_880.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_298.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_919.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2731.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_841.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_846.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_864.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_904.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_907.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_884.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_914.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_857.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Red_s/ManzanaV_283.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_863.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_849.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_835.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_828.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2732.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_925.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_915.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Golden_s/ManzanaV_2743.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_836.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_870.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_832.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_891.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_852.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2617.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_824.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2691.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_918.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2690.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_831.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_922.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_899.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_921.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2667.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2655.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2682.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_850.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2679.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2697.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_909.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2653.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2648.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_847.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2644.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2629.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2705.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2656.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2615.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2709.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2614.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2666.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2643.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_843.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2635.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_829.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2674.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2651.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2688.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2676.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2707.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2706.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/validation/Granny_s/ManzanaV_876.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2685.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2657.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2701.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2692.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2662.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2665.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2686.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2633.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2616.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2714.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2637.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2669.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2703.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2649.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2613.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2639.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2634.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2689.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2673.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2661.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2622.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2678.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2645.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2694.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2620.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2658.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2619.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2627.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2610.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2628.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2683.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2672.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2696.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2624.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2684.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2663.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2642.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2677.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2641.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2612.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2681.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2652.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2632.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2636.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2630.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Gala_s/Gala-s (278).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2693.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Gala_s/Gala-s (267).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2638.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Gala_s/Gala-s (257).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Golden_s/ManzanaV_2699.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Gala_s/Gala-s (238).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/test/Gala_s/Gala-s (235).png
# ...
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Gala_s/Gala-s (288).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (152).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_422.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_557.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (49).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_470.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (50).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (85).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (61).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (237).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (81).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Gala_s/Gala-s (294).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (134).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (249).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Gala_s/Gala-s (120).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (44).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (80).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_440.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (129).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_447.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_547.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (115).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_502.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_539.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (279).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_588.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_376.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_515.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Gala_s/Gala-s (88).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (271).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (56).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_509.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_403.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_370.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_309.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (33).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_601.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (27).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (3).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (45).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (99).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_330.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (122).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_483.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_546.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_559.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (193).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (183).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_396.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_600.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (297).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_410.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (164).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_589.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_383.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_414.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_581.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_428.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_442.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (145).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (201).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_430.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (158).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (93).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_513.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (135).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_608.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_500.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_448.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_596.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_489.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_328.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (103).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_390.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_322.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (157).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (79).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_476.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (74).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_409.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (104).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (231).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (243).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (19).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (13).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_478.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_520.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_352.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_321.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (236).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_435.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (141).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_495.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_496.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_311.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_366.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (206).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_424.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_459.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (217).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_453.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (194).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_514.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (105).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_583.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_587.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (229).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_558.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (116).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (20).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_402.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (169).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_527.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_323.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (195).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_534.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (248).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_340.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (207).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_358.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_595.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_606.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (284).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_441.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_458.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (265).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (111).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_577.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_540.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_482.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (68).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_569.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_446.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_384.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (296).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (128).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_354.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_570.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (39).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (259).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_565.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_464.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (272).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (182).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (153).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_602.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_484.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/Golden-s (67).png
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Golden_s/ManzanaV_348.jpg
#   inflating: /content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2/train/Granny_s/Granny-s (292).png

# %% [markdown]
# Importamos los datos, poniendo la dirección donde se encuentran, que en el caso de Colab es la dirección base_dir:

# %%
import os

base_dir = '/content/drive/MyDrive/EXPERIMENTO_TALLER/MANZANAS_COLAB_2'

train_dir =      os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'validation')
test_dir =       os.path.join(base_dir, 'test')

# Directorio con las imagenes de training
train_Gala_s_dir = os.path.join(train_dir, 'Gala_s')
train_Golden_s_dir = os.path.join(train_dir, 'Golden_s')
train_Granny_s_dir = os.path.join(train_dir, 'Granny_s')
train_Red_s_dir = os.path.join(train_dir, 'Red_s')


# Directorio con las imagenes de validation
validation_Gala_s_dir = os.path.join(validation_dir, 'Gala_s')
validation_Golden_s_dir =os.path.join(validation_dir, 'Golden_s')
validation_Granny_s_dir = os.path.join(validation_dir, 'Granny_s')
validation_Red_s_dir = os.path.join(validation_dir, 'Red_s')

# Directorio con las imagenes de test
test_Gala_s_dir = os.path.join(test_dir, 'Gala_s')
test_Golden_s_dir = os.path.join (test_dir, 'Golden_s')
test_Granny_s_dir = os.path.join (test_dir, 'Granny_s')
test_Red_s_dir = os.path.join(test_dir, 'Red_s')

# %% [markdown]
# Imprimo la cantidad de imágenes a utilizar:

# %%
print('total imagenes entrenamiento Gala_s :', len(os.listdir(train_Gala_s_dir) ))
print('total imagenes entrenamiento Golden_s :', len(os.listdir(train_Golden_s_dir) ))
print('total imagenes entrenamiento Granny_s :', len(os.listdir(train_Granny_s_dir) ))
print('total imagenes entrenamiento Red_s :', len(os.listdir(train_Red_s_dir) ))


print('total imagenes validacion Gala_s :', len(os.listdir(validation_Gala_s_dir) ))
print('total imagenes validacion Golden_s :',len(os.listdir(validation_Golden_s_dir) ) )
print('total imagenes validacion Granny_s :',len(os.listdir(validation_Granny_s_dir) ) )
print('total imagenes validacion Red_s :', len(os.listdir(validation_Red_s_dir) ))


print('total imagenes prueba Gala_s :',len(os.listdir(test_Gala_s_dir) ) )
print('total imagenes prueba Golden_s :',len(os.listdir(test_Golden_s_dir) ))
print('total imagenes prueba Granny_s :',len(os.listdir(test_Granny_s_dir) ) )
print('total imagenes prueba Red_s :', len(os.listdir(test_Red_s_dir) ))
# Out:
# total imagenes entrenamiento Gala_s : 420
# total imagenes entrenamiento Golden_s : 420
# total imagenes entrenamiento Granny_s : 420
# total imagenes entrenamiento Red_s : 420
# total imagenes validacion Gala_s : 90
# total imagenes validacion Golden_s : 90
# total imagenes validacion Granny_s : 90
# total imagenes validacion Red_s : 90
# total imagenes prueba Gala_s : 90
# total imagenes prueba Golden_s : 90
# total imagenes prueba Granny_s : 90
# total imagenes prueba Red_s : 90

# %% [markdown]
# Acondicionamiento y normalización de las imágenes:

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator( rescale = 1.0/255. )
validation_datagen  = ImageDataGenerator( rescale = 1.0/255. )
test_datagen  = ImageDataGenerator( rescale = 1.0/255. )


train_generator = train_datagen.flow_from_directory(train_dir,
                                                    batch_size=90,
                                                    class_mode='categorical',
                                                    target_size=(256, 256))

validation_generator =  validation_datagen.flow_from_directory(validation_dir,
                                                         batch_size=90,
                                                         class_mode  = 'categorical',
                                                         target_size = (256, 256))


test_generator =  test_datagen.flow_from_directory(test_dir,
                                                         batch_size=90,
                                                         class_mode  = 'categorical',
                                                         target_size = (256, 256),
                                                         shuffle = False)
# Out:
# Found 1680 images belonging to 4 classes.
# Found 360 images belonging to 4 classes.
# Found 360 images belonging to 4 classes.

# %% [markdown]
# #Experimento
# # Arquitectura VGG16 con Fine Tuning

# %%
from tensorflow.keras.applications import VGG16

pre_trained_model = VGG16(input_shape = (256, 256, 3),
                                include_top = False,
                                weights = 'imagenet')

pre_trained_model.trainable = True

set_trainable = False


for layer in pre_trained_model.layers:
  #if layer.name == 'block5_conv1':
   # set_trainable = True
  #if layer.name == 'block5_conv2':
   # set_trainable = True
  if layer.name == 'block5_conv3':
    set_trainable = True
  if set_trainable:
    layer.trainable = True
  else:
    layer.trainable = False

pre_trained_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 2359808 (9.00 MB)
# Non-trainable params: 12354880 (47.13 MB)
# _________________________________________________________________

# %%
from tensorflow.keras import Model

from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

modelFT = Sequential()
modelFT.add(pre_trained_model)
modelFT.add(Flatten())
modelFT.add(Dense(4096, activation='relu'))
modelFT.add(Dense(512, activation='relu'))
modelFT.add(Dense(4, activation='sigmoid'))


modelFT.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 4096)              134221824
#
#  dense_1 (Dense)             (None, 512)               2097664
#
#  dense_2 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 151036228 (576.16 MB)
# Trainable params: 138681348 (529.03 MB)
# Non-trainable params: 12354880 (47.13 MB)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

modelFT.compile(optimizer=RMSprop(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics = ['acc'])

# %%
batch_size = 90
steps_per_epoch = train_generator.n // batch_size
validation_steps = validation_generator.n // batch_size

print (steps_per_epoch)
print (validation_steps)
# Out:
# 18
# 4

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
checkpoint_VGG16_FT = ModelCheckpoint(filepath="pesos_VGG16_FT.weights.best.hdf5",save_best_only=True,verbose=1)

# %%
early_stop= EarlyStopping(monitor="val_loss",patience=10,restore_best_weights=True,mode="min")

# %%
historyFT = modelFT.fit(
            train_generator,
            validation_data = validation_generator,
            steps_per_epoch = steps_per_epoch,
            epochs = 50,
            validation_steps = validation_steps,
            verbose = 2,callbacks=[checkpoint_VGG16_FT,early_stop])
# Out:
# Epoch 1/50
#
# Epoch 1: val_loss improved from inf to 0.77904, saving model to pesos_VGG16_FT.weights.best.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 18/18 - 66s - loss: 2.4044 - acc: 0.4994 - val_loss: 0.7790 - val_acc: 0.7167 - 66s/epoch - 4s/step
# Epoch 2/50
#
# Epoch 2: val_loss improved from 0.77904 to 0.45248, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 39s - loss: 0.5247 - acc: 0.7686 - val_loss: 0.4525 - val_acc: 0.7528 - 39s/epoch - 2s/step
# Epoch 3/50
#
# Epoch 3: val_loss did not improve from 0.45248
# 18/18 - 27s - loss: 0.2627 - acc: 0.9031 - val_loss: 0.6474 - val_acc: 0.7639 - 27s/epoch - 1s/step
# Epoch 4/50
#
# Epoch 4: val_loss improved from 0.45248 to 0.20774, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 33s - loss: 0.1625 - acc: 0.9346 - val_loss: 0.2077 - val_acc: 0.9194 - 33s/epoch - 2s/step
# Epoch 5/50
#
# Epoch 5: val_loss improved from 0.20774 to 0.05148, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 38s - loss: 0.1557 - acc: 0.9591 - val_loss: 0.0515 - val_acc: 0.9944 - 38s/epoch - 2s/step
# Epoch 6/50
#
# Epoch 6: val_loss did not improve from 0.05148
# 18/18 - 27s - loss: 0.1679 - acc: 0.9560 - val_loss: 0.1215 - val_acc: 0.9556 - 27s/epoch - 1s/step
# Epoch 7/50
#
# Epoch 7: val_loss improved from 0.05148 to 0.04581, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 39s - loss: 0.0152 - acc: 0.9987 - val_loss: 0.0458 - val_acc: 0.9917 - 39s/epoch - 2s/step
# Epoch 8/50
#
# Epoch 8: val_loss did not improve from 0.04581
# 18/18 - 26s - loss: 0.1260 - acc: 0.9686 - val_loss: 0.0573 - val_acc: 0.9833 - 26s/epoch - 1s/step
# Epoch 9/50
#
# Epoch 9: val_loss did not improve from 0.04581
# 18/18 - 26s - loss: 0.0073 - acc: 1.0000 - val_loss: 0.0503 - val_acc: 0.9833 - 26s/epoch - 1s/step
# Epoch 10/50
#
# Epoch 10: val_loss improved from 0.04581 to 0.04081, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 42s - loss: 0.0040 - acc: 1.0000 - val_loss: 0.0408 - val_acc: 0.9889 - 42s/epoch - 2s/step
# Epoch 11/50
#
# Epoch 11: val_loss did not improve from 0.04081
# 18/18 - 27s - loss: 0.2285 - acc: 0.9610 - val_loss: 0.0715 - val_acc: 0.9722 - 27s/epoch - 1s/step
# Epoch 12/50
#
# Epoch 12: val_loss did not improve from 0.04081
# 18/18 - 28s - loss: 0.0075 - acc: 1.0000 - val_loss: 0.0529 - val_acc: 0.9833 - 28s/epoch - 2s/step
# Epoch 13/50
#
# Epoch 13: val_loss did not improve from 0.04081
# 18/18 - 28s - loss: 0.0034 - acc: 1.0000 - val_loss: 0.0430 - val_acc: 0.9861 - 28s/epoch - 2s/step
# Epoch 14/50
#
# Epoch 14: val_loss improved from 0.04081 to 0.03644, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 36s - loss: 0.0020 - acc: 1.0000 - val_loss: 0.0364 - val_acc: 0.9861 - 36s/epoch - 2s/step
# Epoch 15/50
#
# Epoch 15: val_loss improved from 0.03644 to 0.02963, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 34s - loss: 0.0012 - acc: 1.0000 - val_loss: 0.0296 - val_acc: 0.9861 - 34s/epoch - 2s/step
# Epoch 16/50
#
# Epoch 16: val_loss did not improve from 0.02963
# 18/18 - 27s - loss: 8.4072e-04 - acc: 1.0000 - val_loss: 0.0346 - val_acc: 0.9889 - 27s/epoch - 1s/step
# Epoch 17/50
#
# Epoch 17: val_loss did not improve from 0.02963
# 18/18 - 26s - loss: 6.9377e-04 - acc: 1.0000 - val_loss: 0.0300 - val_acc: 0.9889 - 26s/epoch - 1s/step
# Epoch 18/50
#
# Epoch 18: val_loss improved from 0.02963 to 0.02459, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 33s - loss: 4.4422e-04 - acc: 1.0000 - val_loss: 0.0246 - val_acc: 0.9944 - 33s/epoch - 2s/step
# Epoch 19/50
#
# Epoch 19: val_loss did not improve from 0.02459
# 18/18 - 27s - loss: 3.7305e-04 - acc: 1.0000 - val_loss: 0.0346 - val_acc: 0.9861 - 27s/epoch - 2s/step
# Epoch 20/50
#
# Epoch 20: val_loss did not improve from 0.02459
# 18/18 - 26s - loss: 2.7888e-04 - acc: 1.0000 - val_loss: 0.0251 - val_acc: 0.9889 - 26s/epoch - 1s/step
# Epoch 21/50
#
# Epoch 21: val_loss improved from 0.02459 to 0.02306, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 38s - loss: 2.2804e-04 - acc: 1.0000 - val_loss: 0.0231 - val_acc: 0.9917 - 38s/epoch - 2s/step
# Epoch 22/50
#
# Epoch 22: val_loss did not improve from 0.02306
# 18/18 - 27s - loss: 1.9622e-04 - acc: 1.0000 - val_loss: 0.0257 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 23/50
#
# Epoch 23: val_loss did not improve from 0.02306
# 18/18 - 27s - loss: 1.7530e-04 - acc: 1.0000 - val_loss: 0.0238 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 24/50
#
# Epoch 24: val_loss did not improve from 0.02306
# 18/18 - 26s - loss: 1.4974e-04 - acc: 1.0000 - val_loss: 0.0245 - val_acc: 0.9917 - 26s/epoch - 1s/step
# Epoch 25/50
#
# Epoch 25: val_loss did not improve from 0.02306
# 18/18 - 26s - loss: 1.4225e-04 - acc: 1.0000 - val_loss: 0.0270 - val_acc: 0.9917 - 26s/epoch - 1s/step
# Epoch 26/50
#
# Epoch 26: val_loss improved from 0.02306 to 0.01995, saving model to pesos_VGG16_FT.weights.best.hdf5
# 18/18 - 36s - loss: 1.2113e-04 - acc: 1.0000 - val_loss: 0.0200 - val_acc: 0.9944 - 36s/epoch - 2s/step
# Epoch 27/50
#
# Epoch 27: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 1.1614e-04 - acc: 1.0000 - val_loss: 0.0255 - val_acc: 0.9889 - 27s/epoch - 1s/step
# Epoch 28/50
#
# Epoch 28: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 1.0580e-04 - acc: 1.0000 - val_loss: 0.0249 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 29/50
#
# Epoch 29: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 9.5684e-05 - acc: 1.0000 - val_loss: 0.0258 - val_acc: 0.9889 - 27s/epoch - 1s/step
# Epoch 30/50
#
# Epoch 30: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 9.5377e-05 - acc: 1.0000 - val_loss: 0.0239 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 31/50
#
# Epoch 31: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 8.8230e-05 - acc: 1.0000 - val_loss: 0.0215 - val_acc: 0.9944 - 27s/epoch - 2s/step
# Epoch 32/50
#
# Epoch 32: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 8.4861e-05 - acc: 1.0000 - val_loss: 0.0232 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 33/50
#
# Epoch 33: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 7.6413e-05 - acc: 1.0000 - val_loss: 0.0228 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 34/50
#
# Epoch 34: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 7.5421e-05 - acc: 1.0000 - val_loss: 0.0230 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 35/50
#
# Epoch 35: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 7.2596e-05 - acc: 1.0000 - val_loss: 0.0261 - val_acc: 0.9917 - 27s/epoch - 1s/step
# Epoch 36/50
#
# Epoch 36: val_loss did not improve from 0.01995
# 18/18 - 27s - loss: 6.3641e-05 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 0.9917 - 27s/epoch - 2s/step

# %% [markdown]
# Cargamos los mejores pesos del entrenamiento:

# %%
modelFT.load_weights("/content/pesos_VGG16_FT.weights.best.hdf5")

# %%
import numpy as np

# %% [markdown]
# Realizamos la evaluación del Accuracy

# %%
test_lost, test_acc= modelFT.evaluate(test_generator)
print ("Test Accuracy:", test_acc)
# Out:
# 4/4 [==============================] - 4s 759ms/step - loss: 0.0222 - acc: 0.9917
# Test Accuracy: 0.9916666746139526

# %% [markdown]
# Comparamos el entrenamiento y la validación del Accuracy(exactitud) y el loss (perdida)

# %%
import matplotlib.pyplot as plt

acc      = historyFT.history[     'acc' ]
val_acc  = historyFT.history[ 'val_acc' ]
loss     = historyFT.history[    'loss' ]
val_loss = historyFT.history['val_loss' ]

epochs    = range(1,len(acc)+1,1) # obtener número de epochs

f, ax = plt.subplots(figsize=(10,10))
ax.plot  ( epochs,     acc, 'r--', label=''  )
ax.plot  ( epochs, val_acc,  'b', label='')
ax.set_title ("")
ax.set_ylabel('acc')
ax.set_xlabel('epochs')
ax.legend()
f.savefig("Training and Validation Accuracy VGG16_FT.png")
f.savefig("Training and Validation Accuracy VGG16_FT.eps")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
f, ax = plt.subplots(figsize=(10,10))
ax.plot  ( epochs,     loss, 'r--', label=''  )
ax.plot  ( epochs, val_loss ,  'b', label='' )
ax.set_title ("")
ax.set_ylabel('loss')
ax.set_xlabel('epochs')
ax.legend()
f.savefig("Training and Validation Loss VGG16_FT.png")
f.savefig("Training and Validation Loss VGG16_FT.eps")
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# # Matriz de Confusión

# %%
from sklearn.metrics import confusion_matrix, accuracy_score,classification_report

# %%
import numpy as np
import seaborn as sns

# %%
# Funcion que permite graficar las matrices de confusion
def plot_heatmap(y_true, y_pred, class_names, ax, title):
    cm = confusion_matrix(y_true, y_pred)
    sns.heatmap(
        cm,
        annot=True,
        square=True,
        xticklabels=class_names,
        yticklabels=class_names,
        fmt='d',
        cmap=plt.cm.Blues,
        cbar=False,
        ax=ax
    )
    ax.set_title(title, fontsize=16)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
    ax.set_ylabel('True Label', fontsize=12)
    ax.set_xlabel('Predicted Label', fontsize=12)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
plot_heatmap(test_generator.classes, np.argmax(modelFT.predict(test_generator),axis=1), test_generator.class_indices.keys() , ax, title="VGG16_FT")
fig.savefig("VGG16_FT matrix_confusion.png")
fig.savefig("VGG16_FT matrix_confusion.eps")
# Out:
# 4/4 [==============================] - 4s 765ms/step

# %% [markdown]
# # Métricas de desempeño del clasificador

# %%
print(classification_report(test_generator.classes, np.argmax(modelFT.predict(test_generator),axis=1), target_names=test_generator.class_indices ))
# Out:
# 4/4 [==============================] - 3s 707ms/step
#               precision    recall  f1-score   support
#
#       Gala_s       0.99      1.00      0.99        90
#     Golden_s       0.99      1.00      0.99        90
#     Granny_s       1.00      0.98      0.99        90
#        Red_s       0.99      0.99      0.99        90
#
#     accuracy                           0.99       360
#    macro avg       0.99      0.99      0.99       360
# weighted avg       0.99      0.99      0.99       360

# %% [markdown]
# Guardamos el History

# %%
import pandas as pd

# assuming you stored your model.fit results in a 'history' variable:
#history = model.fit(x_train, y_train, epochs=10)

# convert the history.history dict to a pandas DataFrame:
hist_df = pd.DataFrame(historyFT.history)

# save to json:
hist_json_file = 'history.json'
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv:
hist_csv_file = 'history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)
